# %% [markdown]
# # 1. Overview and Setup
#
# This notebook contains the code used for the network analysis discussed in the accompanying paper.
#
# The aim of the project is to examine whether Empirical Network Analysis (ENA) can support a general account of the diffusion of scientific innovations. To do so, I apply a procedure similar to the one used by Herfeld and Doehne for rational choice theory to a different case study: the diffusion of Shannon’s information theory.
#
# The collection and preprocessing of the bibliographic data were carried out separately, following the procedure described in the paper. The notebook therefore starts from two CSV files: one containing the nodes of the network and their metadata, and one containing the edges.
#
# The notebook is organized as follows:
#
# - **Section 1** loads the data and builds the graph with NetworkX.
# - **Section 2** identifies the epistemic core, first by k-core decomposition and then by an alternative procedure based on degree centrality.
# - **Section 3** identifies communities with the Girvan–Newman algorithm and compares the result with a Louvain partition using the Adjusted Rand Index (ARI).
# - **Section 4** identifies the roles of elaborators and translators on the basis of the analytical criteria discussed in the paper.
#
# This notebook is meant to document the computational analysis. The philosophical motivation, the justification of the methodological choices, and the interpretation of the results are given in the paper.

# %% [markdown]
# ##1.1 Upload the Data

# %%
import pandas as pd


nodes_id= "1l4dcAwUMHw9Zee_uedg0v5X8AvWmBhyV"
edges_id= "16EqZKZk4fIsGaECHbQoPuBcaLDXAJR6d"

nodes_link = f"https://drive.google.com/uc?export=download&id={nodes_id}"
edges_link = f"https://drive.google.com/uc?export=download&id={edges_id}"


nodes_df = pd.read_csv(nodes_link)
edges_df = pd.read_csv(edges_link)



nodes_df.head()
# Out:
#                             node_id  reference_occurrence  degree  year  \
# 0  https://openalex.org/W2069271851                     3       1  1972
# 1  https://openalex.org/W2148962857                    10       1  1955
# 2  https://openalex.org/W1568559199                     3       1  1970
# 3  https://openalex.org/W2117476053                     3       1  1956
# 4  https://openalex.org/W1973071586                    10       2  1972
#
#                                   doi  \
# 0         10.1137/1.9781611970654.ch1
# 1                     10.2307/1884852
# 2                  10.1007/bf00533669
# 3  10.1002/j.1538-7305.1956.tb02379.x
# 4                  10.1007/bf02018661
#
#                                                title  cited_by_count  \
# 0                    1. Bayesian Statistics a Review             530
# 1              A Behavioral Model of Rational Choice           14887
# 2  A characterization of limiting distributions o...             278
# 3              A Class of Binary Signaling Alphabets             195
# 4  A class of measures of informativity of observ...             195
#
#             authors
# 0     D. V. Lindley
# 1  Herbert A. Simon
# 2    Jaroslav H�jek
# 3        D. Slepian
# 4      Imre Csiszár

# %% [markdown]
# A note on the attributes:
#
# - **reference_occurence** indicates how many times the publication was cited in the publications that also cite Shannon’s *A Mathematical Theory of Communication*.
# - **degree** is the number of other publications to which a publication is connected in the network.
# - **cited_by_count** is the overall citation count of the publication in the broader bibliographic record.

# %% [markdown]
# ##1.2 Graph with NetworkX

# %%
import networkx as nx


# here the graph is created, using the CSV files. attributes are also added to the nodes

G = nx.Graph()


for _, row in nodes_df.iterrows():
    node_id = row["node_id"]
    attrs = row.drop("node_id").to_dict()
    G.add_node(node_id, **attrs)

for _, row in edges_df.iterrows():
    source = row["source"]
    target = row["target"]
    G.add_edge(source, target)

print(G.number_of_nodes(), "nodes")
print(G.number_of_edges(), "edges")
# Out:
# 659 nodes
# 1048 edges

# %% [markdown]
# ##1.3 Plot

# %%
import plotly.graph_objects as go



pos = nx.spring_layout(G, k=0.15, iterations=50, seed=42)

def plot_graph(G, title = None): #the function plots the graph using plotly

  edge_x = []
  edge_y = []

  for u, v in G.edges():
      x0, y0 = pos[u]
      x1, y1 = pos[v]
      edge_x.extend([x0, x1, None])
      edge_y.extend([y0, y1, None])

  edge_trace = go.Scatter(
      x=edge_x,
      y=edge_y,
      mode="lines",
      line=dict(width=0.5, color="rgba(150,150,150,0.4)"),
      hoverinfo="skip"
  )


  node_x = []
  node_y = []
  hover_text = []
  node_size = []

  for n, attrs in G.nodes(data=True):
      x, y = pos[n]
      node_x.append(x)
      node_y.append(y)


      txt = f"<b>ID</b>: {n}<br>"
      for k, v in attrs.items():
          txt += f"<b>{k}</b>: {v}<br>"
      hover_text.append(txt)


      s = attrs.get("size", 8)
      try:
          s = float(s)
      except:
          s = 8
      node_size.append(s)

  node_trace = go.Scatter(
      x=node_x,
      y=node_y,
      mode="markers",
      hoverinfo="text",
      text=hover_text,
      marker=dict(
          size=node_size,
          sizemode="diameter",
          line=dict(width=0.5, color="white")
      )
  )


  fig = go.Figure(data=[edge_trace, node_trace])

  fig.update_layout(
      title= title,
      showlegend=False,
      hovermode="closest",
      margin=dict(l=10, r=10, t=40, b=10),
      xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
      yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
      height=900
  )

  fig.show()

plot_graph(G, title = "Spread of Information Theory")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="46d0f738-7f81-41fb-9d28-93220aadd667" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46d0f738-7f81-41fb-9d28-93220aadd667")) {                    Plotly.newPlot(                        "46d0f738-7f81-41fb-9d28-93220aadd667",                        [{"hoverinfo":"skip","line":{"color":"rgba(150,150,150,0.4)","width":0.5},"mode":"lines","x":[-0.1884032588668762,-0.20638114863067825,null,0.7598874822777962,0.7392272234636184,null,-0.3849612032316872,-0.41042811571599486,null,0.12503404428748421,0.06425027132581958,null,-0.16423776245665717,-0.19349071263164622,null,-0.16423776245665717,-0.11872158412881154,null,0.2078088310497395,0.2522707948883274,null,0.2078088310497395,0.15756327093167802,null,-0.04356819891241091,-0.020923906162001148,null,-0.04356819891241091,-0.06680021449972304,null,-0.04356819891241091,-0.060235442271781084,null,-0.04356819891241091,-0.029860201800256198,null,-0.04356819891241091,-0.025568916055479382,null,-0.10186147248080726,0.02628461704427705,null,-0.10186147248080726,-0.19349071263164622,null,-0.10186147248080726,-0.1612043327852589,null,-0.10186147248080726,-0.11243499566295656,null,-0.05604283943700821,-0.059380255101538236,null,-0.05604283943700821,-0.05189688767953057,null,-0.08972049788602168,-0.19349071263164622,null,-0.08972049788602168,-0.059997202058996106,null,-0.08972049788602168,-0.05969480989871469,null,-0.08972049788602168,-0.08830687767157874,null,-0.08972049788602168,-0.11872158412881154,null,-0.08972049788602168,-0.06522370343431445,null,-0.08972049788602168,-0.10703175153846939,null,-0.08972049788602168,-0.06783893469530747,null,-0.21807138480139696,-0.19349071263164622,null,-0.5789236675720951,-0.5559669860847078,null,-0.26878081861876135,-0.3021390101359195,null,-0.26878081861876135,-0.3089722014733136,null,-0.26878081861876135,-0.29353328293212877,null,-0.26878081861876135,-0.2701420767348751,null,-0.26878081861876135,-0.24475420526314745,null,-0.26878081861876135,-0.2256031505397595,null,-0.26878081861876135,-0.2645293813458414,null,0.4982989758446426,0.542124640138516,null,0.4982989758446426,0.43580554824616924,null,0.25051191273348533,0.2522707948883274,null,0.25051191273348533,0.15649873904006834,null,0.25051191273348533,0.3121811087528817,null,0.09154043353416698,0.14360102722531687,null,0.09154043353416698,0.1854592699069572,null,0.09154043353416698,-0.02382438009492051,null,-0.3765904691542959,-0.3644413162902053,null,-0.3765904691542959,-0.3928320655574508,null,-0.3765904691542959,-0.30563824006741974,null,-0.14822605997798435,-0.15759673051793183,null,-0.14822605997798435,-0.16403648879307364,null,-0.14822605997798435,-0.19292759919368485,null,-0.14822605997798435,-0.15725293392751083,null,-0.27814577860333073,-0.26807163032928977,null,-0.27814577860333073,-0.25023725780739203,null,-0.27814577860333073,-0.28530507941083877,null,-0.27814577860333073,-0.2927498110770757,null,-0.27814577860333073,-0.2737143818154931,null,-0.27814577860333073,-0.32572775438989676,null,-0.15559063090878783,-0.11650186901820438,null,-0.06068525574587595,-0.10817834945356203,null,0.2809941053574874,0.2215235234842849,null,-0.25091883462879255,-0.197395275132786,null,-0.25091883462879255,-0.2235725534347822,null,-0.060235442271781084,-0.029860201800256198,null,-0.060235442271781084,-0.025568916055479382,null,-0.060235442271781084,-0.11274467540940904,null,-0.060235442271781084,-0.06680021449972304,null,-0.060235442271781084,-0.07540411767564827,null,-0.060235442271781084,-0.020923906162001148,null,0.7997795437957645,0.8020985424709921,null,0.7997795437957645,0.8255948226049273,null,0.7997795437957645,0.7804363868800875,null,0.7997795437957645,0.7992431343735537,null,0.7997795437957645,0 ...

# %% [markdown]
# # 2. Epistemic Core
#
# This section identifies the epistemic core of the network.
#
# In Herfeld and Doehne’s approach, the epistemic core is the “backbone” of the epistemic domain: conceptually, it consists of those publications that engage with the innovation early on, develop it, and make it suitable for application across different fields. Analytically, they identify it by means of k-core decomposition.
#
# I follow that procedure first, and then consider an alternative approach based on degree centrality. The comparison is relevant because one of the questions raised in the paper is whether the identification of the epistemic core is robust with respect to different analytical choices.

# %% [markdown]
# ##2.1 Epistemic Core with K-core Decomposition

# %%
#k-core decomposition--> there is a built-in function in NetworkX

for n in range (0, 12):

  G_core = nx.k_core(G, k=n)

  print("K =", n, "nodes=", G_core.number_of_nodes())
# Out:
# K = 0 nodes= 659
# K = 1 nodes= 659
# K = 2 nodes= 309
# K = 3 nodes= 180
# K = 4 nodes= 94
# K = 5 nodes= 40
# K = 6 nodes= 23
# K = 7 nodes= 23
# K = 8 nodes= 22
# K = 9 nodes= 15
# K = 10 nodes= 11
# K = 11 nodes= 0

# %% [markdown]
# First, I try with **k = 7**, in order to see whether the result is comparable to the case studied by Herfeld and Doehne.
#
# However, the resulting subgraph does not seem to be a good candidate for the epistemic core. Rather than capturing a broadly interdisciplinary backbone of the diffusion of information theory, it mainly selects publications belonging to a more specialized area, especially cognitive science. For that reason, I do not retain it as the epistemic core.

# %%
G_core = nx.k_core(G, k=7)
plot_graph(G_core, title = "7-core")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
# 502  10.1016/b978-0-12-010904-3.50011-7
# 511            10.1109/tit.1975.1055469
# 528                                 NaN
# 546              10.1214/aop/1176996549
# 549            10.1109/tit.1975.1055346
# 551        10.1016/0020-0255(75)90036-5
# 553        10.1016/0020-0255(75)90017-1
# 560       10.1016/s0019-9958(66)80018-9
# 588                     10.2307/1934145
# 606  10.1002/j.1538-7305.1975.tb02040.x
# 614                   10.1119/1.1935945
# 617           10.1080/00207166808803030
# 618                     10.2307/1426331
# 641                   10.1520/stp34718s
#
#                                                  title  cited_by_count  \
# 6     A Class of Solutions for Group Decision Problems            1090
# 9                 A coding theorem and Rényi's entropy             276
# 17   A COMPOSITE RATING OF ALGAE TOLERATING ORGANIC...             569
# 18   A conditional entropy bound for a pair of disc...             146
# 23   A definition of a nonprobabilistic entropy in ...            2241
# 26      A formal theory of inductive inference. Part I            1154
# 27     A formal theory of inductive inference. Part II            1774
# 53   A proof of the data compression theorem of Sle...             387
# 55   A simple converse for broadcast channels with ...             458
# 56   A simple derivation of the coding theorem and ...             696
# 64   A theorem on the entropy of certain binary seq...             172
# 73   An achievable rate region for the broadcast ch...             183
# 86              An Introduction to Information Theory.             777
# 90   An Introduction to the Physical Theories of Eq...              52
# 119                                 Broadcast channels            1709
# 183  Diversity in some south African diatom associa...             131
# 260              <i>Science and Information Theory</i>            1923
# 277                                 Information radius             226
# 280                                 Information Theory            3905
# 281                     Information Theory and Coding.            1088
# 283      Information Theory and Reliable Communication            3999
# 284       Information Theory and Statistical Mechanics           12669
# 285   Information Theory and Statistical Mechanics. II            3160
# 286                 Information Theory and Statistics.            1540
# 293                           Intervall‐wertige Mengen             206
# 296  Irreversibility and Heat Generation in the Com...            4677
# 311  Logical basis for information theory and proba...             601
# 314  Lower bounds to error probability for coding o...             365
# 320    Mathematical Foundations of Information Theory.            1476
# 337                   Multi-way communication channels             613
# 345  Noiseless coding of correlated information sou...            3975
# 364             On Measures of Entropy and Information            3952
# 366  On Sequences of Pairs of Dependent Random Vari...             324
# 382  On the Length of Programs for Computing Finite...             911
# 446  Quantification method of classification proces...             840
# 459  Random coding theorem for broadcast channels w...             513
# 466               Recent results in the Shannon theory             635
# 485                     Science and information theory            1516
# 489  Self-Consistent Equations Including Exchange a...           61878
# 502                Some Advances in Broadcast Channels             126
# 511  Source coding with side information and a conv...             447
# 528  System of water quality from the biological po...             710
# 546  The Capacity Region of a Channel with Two Send...             347
# 549  The common information of two dependent random...             505
# 551  The concept of a linguistic variable and its a...           11934
# 553  The concept of a linguistic variable and its a...           12161
# 560                 The definition of random sequences            1217
# 588  The Nonconcept of Species Diversity: A Critiqu...            4183
# 606                               The Wire-Tap Channel            7038
# 614  Thermodynamics, An Introduction to the Physica...             268
# 617  Three approaches to the quantitative definitio...            2023
# 618              Three-terminal communication channels            1522
# 641  Use of Algae, Especially Diatoms, in the Asses...             137
#
#                                                authors
# 6                                             P. L. Yu
# 9                                       L. L. Campbell
# 17                                    C. Mervin Palmer
# 18                      H. S. Witsenhausen; A.D. Wyner
# 23                            Aldo de Luca; S. Termini
# 26                                   Ray J. Solomonoff
# 27                                   Ray J. Solomonoff
# 53                                     Thomas M. Cover
# 55                                         P. Bergmans
# 56                                  Robert G. Gallager
# 64                            Abraham J. Wyner; J. Ziv
# 73                                     Thomas M. Cover
# 86                            C. L. Mallows; F.M. Reza
# 90                        Herbert B. Callen; J. Kestin
# 119                                    Thomas M. Cover
# 183                                   R.E.M. Archibald
# 260                    Léon Brillouin; R. W. Hellwarth
# 277                                       Robin Sibson
# 280                                             R. Ash
# 281                            I. J. Good; N. Abramson
# 283                                      David A. Bell
# 284                                       E. T. Jaynes
# 285                                       E. T. Jaynes
# 286                           Meyer Dwass; S. Kullback
# 293                                         K.‐U. Jahn
# 296                                      Rolf Landauer
# 311                                   A. N. Kolmogorov
# 314  Claude E. Shannon; Robert G. Gallager; Elwyn R...
# 320  J. Laurie Snell; Aleksandr I︠A︡kovlevich Khinc...
# 337                                    Rudolf Ahlswede
# 345                              D. Slepian; J.K. Wolf
# 364                                           A. Rényi
# 366                                 H. S. Witsenhausen
# 382                                 Gregory J. Chaitin
# 446                      Jan Havrda; František Charvát
# 459                                        P. Bergmans
# 466                                         A.D. Wyner
# 485                                           S. Charp
# 489                                W. Kohn; L. J. Sham
# 502                                    Thomas M. Cover
# 511                      Rudolf Ahlswede; János Körner
# 528                                        V. Sládeček
# 546                                    Rudolf Ahlswede
# 549                                         A.D. Wyner
# 551                                     Lotfi A. Zadeh
# 553                                        L. A. Zadeh
# 560                                     Per Martin-Löf
# 588                                 Stuart H. Hurlbert
# 606                                         A.D. Wyner
# 614                  Herbert B. Callen; P. W. Bridgman
# 617                                   A. N. Kolmogorov
# 618                           Edward C. van der Meulen
# 641                                         R. Patrick

# %% [markdown]
# ## 2.2 Epistemic Core with Degree Centrality
#
# Here I consider an alternative way of identifying the epistemic core.
#
# Instead of using k-core decomposition, I rank the nodes by degree centrality and take the top 53 publications, so that the size matches that of the epistemic core selected in the previous section. I then compare the two results.
#
# This comparison is not meant to establish that degree centrality is the correct criterion, but to assess how sensitive the identification of the epistemic core is to the analytical method used.

# %%
dc = nx.degree_centrality(G)
top53=sorted(dc.items(), key=lambda x: x[1], reverse=True)[:53]


top53_ids = [n[0] for n in top53]

df_shared = df_core[df_core['node_id'].isin(top53_ids)] #create a dataframe with nodes belonging both to the k-core epistemic core and to the degree centrality epistemic core.
df_shared
# Out:
#                               node_id  reference_occurrence  degree  year  \
# 27   https://openalex.org/W2135625884                    32       9  1964
# 53   https://openalex.org/W2155676967                    11      12  1975
# 56   https://openalex.org/W1993944611                    26      13  1965
# 119  https://openalex.org/W2296441616                    20      11  1972
# 277  https://openalex.org/W4252822198                    12      11  1969
# 280  https://openalex.org/W2947000318                   103      18  1966
# 281   https://openalex.org/W158805393                    73      12  1964
# 283  https://openalex.org/W1989008275                   183      65  1969
# 284  https://openalex.org/W2032558547                   452      32  1957
# 285  https://openalex.org/W4252028749                   164      19  1957
# 286  https://openalex.org/W2317912355                    96      15  1960
# 296  https://openalex.org/W4233798822                    69      12  1961
# 320  https://openalex.org/W2087171258                    62      11  1959
# 345  https://openalex.org/W2099213070                    36      19  1973
# 364  https://openalex.org/W2122882636                   134      12  1961
# 446  https://openalex.org/W2263958071                    43       9  1967
# 588  https://openalex.org/W2104767862                    29      12  1971
# 606  https://openalex.org/W2043769961                    35      11  1975
# 617  https://openalex.org/W2005097301                    41       9  1968
#
#                                     doi  \
# 27        10.1016/s0019-9958(64)90131-7
# 53             10.1109/tit.1975.1055356
# 56             10.1109/tit.1965.1053730
# 119            10.1109/tit.1972.1054727
# 277                  10.1007/bf00537520
# 280                                 NaN
# 281                     10.2307/2343598
# 283                10.1049/ep.1969.0319
# 284             10.1103/physrev.106.620
# 285             10.1103/physrev.108.171
# 286                     10.2307/2309734
# 296                  10.1147/rd.53.0183
# 320                     10.2307/2310044
# 345            10.1109/tit.1973.1055037
# 364                                 NaN
# 446                                 NaN
# 588                     10.2307/1934145
# 606  10.1002/j.1538-7305.1975.tb02040.x
# 617           10.1080/00207166808803030
#
#                                                  title  cited_by_count  \
# 27     A formal theory of inductive inference. Part II            1774
# 53   A proof of the data compression theorem of Sle...             387
# 56   A simple derivation of the coding theorem and ...             696
# 119                                 Broadcast channels            1709
# 277                                 Information radius             226
# 280                                 Information Theory            3905
# 281                     Information Theory and Coding.            1088
# 283      Information Theory and Reliable Communication            3999
# 284       Information Theory and Statistical Mechanics           12669
# 285   Information Theory and Statistical Mechanics. II            3160
# 286                 Information Theory and Statistics.            1540
# 296  Irreversibility and Heat Generation in the Com...            4677
# 320    Mathematical Foundations of Information Theory.            1476
# 345  Noiseless coding of correlated information sou...            3975
# 364             On Measures of Entropy and Information            3952
# 446  Quantification method of classification proces...             840
# 588  The Nonconcept of Species Diversity: A Critiqu...            4183
# 606                               The Wire-Tap Channel            7038
# 617  Three approaches to the quantitative definitio...            2023
#
#                                                authors
# 27                                   Ray J. Solomonoff
# 53                                     Thomas M. Cover
# 56                                  Robert G. Gallager
# 119                                    Thomas M. Cover
# 277                                       Robin Sibson
# 280                                             R. Ash
# 281                            I. J. Good; N. Abramson
# 283                                      David A. Bell
# 284                                       E. T. Jaynes
# 285                                       E. T. Jaynes
# 286                           Meyer Dwass; S. Kullback
# 296                                      Rolf Landauer
# 320  J. Laurie Snell; Aleksandr I︠A︡kovlevich Khinc...
# 345                              D. Slepian; J.K. Wolf
# 364                                           A. Rényi
# 446                      Jan Havrda; František Charvát
# 588                                 Stuart H. Hurlbert
# 606                                         A.D. Wyner
# 617                                   A. N. Kolmogorov

# %%
print ("Number of shared nodes:", len(df_shared))
# Out:
# Number of shared nodes: 19

# %% [markdown]
# # 3. Clustering
#
# This section identifies communities in the network.
#
# The purpose of this step is to detect clusters that may correspond, at least approximately, to specialized areas in which information theory was taken up and developed. I first use the Girvan–Newman algorithm, following Herfeld and Doehne’s approach, and then compare the resulting partition with one obtained through the Louvain method. The agreement between the two partitions is measured with the Adjusted Rand Index (ARI).

# %% [markdown]
# ##3.1 Girvan-Newman

# %%
## First I look at the number and size of componenents of the network. I keep those with 15, 10, 9, 9 as clusters, do not consider the smaller ones. I apply the clustering algorithm to the

component_sizes = sorted((len(c) for c in nx.connected_components(G)), reverse=True)


print("number of components:", len(component_sizes))
print(component_sizes[:20])   # the 20 biggest
# Out:
# number of components: 79
# [438, 13, 10, 9, 9, 6, 5, 5, 4, 4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3]

# %% [markdown]
# I keep the four connected components composed of 13, 10, 9, and 9 nodes respectively as communities in their own right, and I apply Girvan–Newman only to the largest connected component.
#
# This choice is partly pragmatic and partly interpretive. Very small components are not especially informative for the purposes of the analysis, whereas these larger disconnected components can still be treated as distinct clusters.

# %%
#Here I create the graph for the largest connected component

largest_cc_nodes = max(nx.connected_components(G), key=len)
Gcc = G.subgraph(largest_cc_nodes).copy()

# %% [markdown]
# ###3.1.1 Apply the Algorithm

# %%
"""
this is the function to run the girvan-newman algorithm
it returns:
  - a dataframe with info for each level of the split (Girvan-Newman works by iiteratively breaking edges, so to each level corresponds a possible different partition)
  - the list of partitions (one for each level. A partition in the list is a tuple of set of nodes)
"""
def run_girvan_newman(G):

    comp = nx.community.girvan_newman(G)

    partitions = []
    rows = []

    level = 0
    for communities in comp:
        level += 1

        communities = tuple(sorted(communities, key=len, reverse=True)) #communities are sorted, from the biggest to the smallest

        partitions.append(communities)

        sizes = [len(c) for c in communities]

        row = {                                           #attributes shown in the dataframe for each partition
            "level": level,
            "n_communities": len(communities),
            "community_sizes": sizes,
            "modularity": nx.community.modularity(G, communities)
        }

        rows.append(row)

    results_df = pd.DataFrame(rows)

    return results_df, partitions

# %%
results_df, partitions = run_girvan_newman(Gcc)   #apply the function to the largest connected component


df_first_levels =results_df[results_df["n_communities"] < 30]

df_first_levels
# Out:
#     level  n_communities                                    community_sizes  \
# 0       1              2                                          [402, 36]
# 1       2              3                                      [339, 63, 36]
# 2       3              4                                 [178, 161, 63, 36]
# 3       4              5                             [178, 141, 63, 36, 20]
# 4       5              6                         [178, 128, 63, 36, 20, 13]
# 5       6              7                     [162, 128, 63, 36, 20, 16, 13]
# 6       7              8                  [162, 92, 63, 36, 36, 20, 16, 13]
# 7       8              9               [155, 92, 63, 36, 36, 20, 16, 13, 7]
# 8       9             10           [155, 92, 36, 36, 32, 31, 20, 16, 13, 7]
# 9      10             11        [149, 92, 36, 36, 32, 31, 20, 16, 13, 7, 6]
# 10     11             12     [92, 82, 67, 36, 36, 32, 31, 20, 16, 13, 7, 6]
# 11     12             13  [83, 82, 67, 36, 36, 32, 31, 20, 16, 13, 9, 7, 6]
# 12     13             14  [83, 67, 44, 38, 36, 36, 32, 31, 20, 16, 13, 9...
# 13     14             15  [78, 67, 44, 38, 36, 36, 32, 31, 20, 16, 13, 9...
# 14     15             16  [67, 44, 40, 38, 38, 36, 36, 32, 31, 20, 16, 1...
# 15     16             17  [67, 44, 40, 38, 38, 36, 36, 31, 23, 20, 16, 1...
# 16     17             18  [67, 44, 40, 38, 38, 36, 36, 23, 22, 20, 16, 1...
# 17     18             19  [67, 40, 38, 38, 36, 36, 32, 23, 22, 20, 16, 1...
# 18     19             20  [67, 40, 38, 38, 36, 32, 23, 22, 22, 20, 16, 1...
# 19     20             21  [64, 40, 38, 38, 36, 32, 23, 22, 22, 20, 16, 1...
# 20     21             22  [58, 40, 38, 38, 36, 32, 23, 22, 22, 20, 16, 1...
# 21     22             23  [58, 40, 38, 36, 33, 32, 23, 22, 22, 20, 16, 1...
# 22     23             24  [44, 40, 38, 36, 33, 32, 23, 22, 22, 20, 16, 1...
# 23     24             25  [44, 40, 38, 36, 33, 23, 22, 22, 22, 20, 16, 1...
# 24     25             26  [44, 38, 36, 33, 32, 23, 22, 22, 22, 20, 16, 1...
# 25     26             27  [44, 38, 36, 32, 29, 23, 22, 22, 22, 20, 16, 1...
# 26     27             28  [44, 36, 35, 32, 29, 23, 22, 22, 22, 20, 16, 1...
# 27     28             29  [44, 36, 32, 32, 29, 23, 22, 22, 22, 20, 16, 1...
#
#     modularity
# 0     0.318997
# 1     0.456187
# 2     0.679122
# 3     0.702017
# 4     0.713017
# 5     0.730326
# 6     0.744677
# 7     0.748692
# 8     0.752623
# 9     0.755766
# 10    0.790015
# 11    0.793013
# 12    0.798293
# 13    0.799835
# 14    0.796025
# 15    0.795885
# 16    0.795655
# 17    0.794633
# 18    0.793745
# 19    0.793605
# 20    0.794103
# 21    0.793856
# 22    0.793208
# 23    0.790558
# 24    0.789331
# 25    0.788728
# 26    0.787971
# 27    0.787403

# %% [markdown]
# I select the partition with **10 communities** in the largest connected component.
#
# This is not the partition with the highest modularity. However, the partitions with more communities tend to include many very small clusters, which are difficult to interpret as meaningful specialized areas. Since the aim here is not simply to maximize modularity but to obtain a partition that can plausibly be related to fields or areas of application, I retain the 10-community solution. Together with the four disconnected components retained above, this yields **14 communities** in total.

# %%
chosen_partition = partitions[8] # I choose the partion at level 9, with 10 communities

"""
    This function assigns a community to the nodes of G:
    - for Gcc, it uses the communities obtained with Girvan-Newman
    - The 4 other biggest components of G become each a community
    - the other receive the value -1

    The function returns a dictionary node_to_community. It also assign the attribute "community" to the nodes of G.


    """

def assign_gn_plus_top_components(
    G,
    gn_partition,
    n_extra_components=4,
    community_attr="community",  #name of the attribute assigned to the nodes of G
    other_value=-1,  #value assigned to the nodes that are not in a community
):

    components_sorted = sorted(nx.connected_components(G), key=len, reverse=True)

    if len(components_sorted) == 0:
        return {}, []

    giant_component = set(components_sorted[0])

    # Check: Girvan-Newman partition must cover precisely largest component.
    gn_nodes = set().union(*gn_partition) if gn_partition else set()
    if gn_nodes != giant_component:
        raise ValueError(
            "Girvan-Newman partition does not coincide with the largest connected component."
        )

    node_to_community = {n: other_value for n in G.nodes()}

    # community of Girvan-Newman
    current_cid = 0
    for comm in gn_partition:
        for node in comm:
            node_to_community[node] = current_cid
        current_cid += 1

    # Other 4 communities
    extra_components = components_sorted[1 : 1 + n_extra_components]
    for comp in extra_components:
        for node in comp:
            node_to_community[node] = current_cid
        current_cid += 1


    nx.set_node_attributes(G, node_to_community, community_attr) #adding the attribute to the nodes of G

    return node_to_community

# %%
node_to_community = assign_gn_plus_top_components(
    G,
    gn_partition=chosen_partition,
    n_extra_components=4,
    community_attr="community",
    other_value=-1
)

# %% [markdown]
# ###3.1.2 Plot the Graph with Communities

# %%
def plot_graph_by_community(
    G,
    community_attr="community",
    title=None,
    height=900,
):
    pos = nx.spring_layout(G, seed=42)

    # edges
    edge_x = []
    edge_y = []
    for u, v in G.edges():
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    edge_trace = go.Scatter(
        x=edge_x,
        y=edge_y,
        mode="lines",
        hoverinfo="skip",
        line=dict(width=0.4, color="rgba(160,160,160,0.3)")
    )

    # colors
    palette = [
        "#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd",
        "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf",
        "#393b79", "#637939", "#8c6d31", "#843c39", "#7b4173"
    ]

    node_x = []
    node_y = []
    node_color = []
    hover_text = []

    for n, attrs in G.nodes(data=True):
        x, y = pos[n]
        node_x.append(x)
        node_y.append(y)

        comm = attrs.get(community_attr, -1)
        if comm == -1:
            color = "#d3d3d3"
        else:
            color = palette[comm % len(palette)]
        node_color.append(color)

        txt = f"<b>ID</b>: {n}<br><b>{community_attr}</b>: {comm}<br>"
        for k, v in attrs.items():
            if k != community_attr:
                txt += f"<b>{k}</b>: {v}<br>"
        hover_text.append(txt)

    node_trace = go.Scatter(
        x=node_x,
        y=node_y,
        mode="markers",
        text=hover_text,
        hoverinfo="text",
        marker=dict(
            size=7,
            color=node_color,
            line=dict(width=0.5, color="white")
        )
    )

    fig = go.Figure(data=[edge_trace, node_trace])

    fig.update_layout(
        title=title,
        showlegend=False,
        hovermode="closest",
        margin=dict(l=10, r=10, t=40, b=10),
        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        height=height
    )

    fig.show()

# %%
plot_graph_by_community(
    G,
    community_attr="community",
    title="Graph with communities"
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="53423ba6-5db9-488d-8ba1-c913d3134069" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53423ba6-5db9-488d-8ba1-c913d3134069")) {                    Plotly.newPlot(                        "53423ba6-5db9-488d-8ba1-c913d3134069",                        [{"hoverinfo":"skip","line":{"color":"rgba(160,160,160,0.3)","width":0.4},"mode":"lines","x":[-0.20561848336965932,-0.22862764265305532,null,0.7055042814537549,0.6877563367172322,null,-0.04153972748791946,-0.03786568160946463,null,0.05135879010219578,0.013065489913865682,null,-0.16171472189243305,-0.1972861483205458,null,-0.16171472189243305,-0.1218301485461448,null,0.18988182295828385,0.23538689081122374,null,0.18988182295828385,0.13898305346052617,null,-0.06568399391742828,-0.03795788084390179,null,-0.06568399391742828,-0.08291490718663753,null,-0.06568399391742828,-0.07019011581382321,null,-0.06568399391742828,-0.05841786918560679,null,-0.06568399391742828,-0.03968344315854923,null,-0.11005553327734026,0.013567422669474662,null,-0.11005553327734026,-0.1972861483205458,null,-0.11005553327734026,-0.17600392653732158,null,-0
#
# 11: ?
#
# 12: Data compression.
#
# 13: ?

# %%
#visualize the communities of the members of the epistemic core

core_nodes_with_communities = []
for node_id, attrs in G_core.nodes(data=True):
    community_id = G.nodes[node_id].get('community', 'N/A')
    core_nodes_with_communities.append({'node_id': node_id, 'title': attrs.get('title'), 'community': community_id})

core_nodes_communities_df = pd.DataFrame(core_nodes_with_communities)
display(core_nodes_communities_df)
# Out:
#                              node_id  \
# 0   https://openalex.org/W2135625884
# 1   https://openalex.org/W1591122409
# 2   https://openalex.org/W1971536606
# 3   https://openalex.org/W2043769961
# 4   https://openalex.org/W2040121225
# 5   https://openalex.org/W2317912355
# 6   https://openalex.org/W1978909760
# 7   https://openalex.org/W2001935257
# 8    https://openalex.org/W610966941
# 9   https://openalex.org/W1989008275
# 10  https://openalex.org/W2017148445
# 11  https://openalex.org/W2263958071
# 12  https://openalex.org/W2005097301
# 13  https://openalex.org/W2122882636
# 14  https://openalex.org/W3190595840
# 15  https://openalex.org/W2088214533
# 16  https://openalex.org/W2067580807
# 17  https://openalex.org/W1992649154
# 18  https://openalex.org/W2067657644
# 19  https://openalex.org/W2230728100
# 20  https://openalex.org/W1592482298
# 21  https://openalex.org/W2032558547
# 22  https://openalex.org/W2296441616
# 23  https://openalex.org/W2033020033
# 24  https://openalex.org/W2099213070
# 25  https://openalex.org/W1981971374
# 26  https://openalex.org/W2159977619
# 27  https://openalex.org/W2947000318
# 28  https://openalex.org/W2143121893
# 29   https://openalex.org/W281620428
# 30  https://openalex.org/W4252822198
# 31  https://openalex.org/W1993944611
# 32  https://openalex.org/W2104767862
# 33  https://openalex.org/W4213350211
# 34  https://openalex.org/W2157041604
# 35  https://openalex.org/W3140053156
# 36  https://openalex.org/W2095087262
# 37  https://openalex.org/W2596773272
# 38  https://openalex.org/W2141432745
# 39  https://openalex.org/W2135460279
# 40   https://openalex.org/W158805393
# 41  https://openalex.org/W2090055713
# 42  https://openalex.org/W2155676967
# 43  https://openalex.org/W4233798822
# 44  https://openalex.org/W2087171258
# 45  https://openalex.org/W2127768309
# 46  https://openalex.org/W4245152641
# 47  https://openalex.org/W2170862660
# 48  https://openalex.org/W2094458162
# 49  https://openalex.org/W4252028749
# 50  https://openalex.org/W1976755248
# 51  https://openalex.org/W2154462988
# 52  https://openalex.org/W2057178439
#
#                                                 title  community
# 0     A formal theory of inductive inference. Part II          6
# 1                 Some Advances in Broadcast Channels          0
# 2               Three-terminal communication channels          0
# 3                                The Wire-Tap Channel          0
# 4   A definition of a nonprobabilistic entropy in ...          7
# 5                  Information Theory and Statistics.          1
# 6   Logical basis for information theory and proba...          6
# 7                A coding theorem and Rényi's entropy          0
# 8   System of water quality from the biological po...          4
# 9       Information Theory and Reliable Communication          0
# 10  The Capacity Region of a Channel with Two Send...          0
# 11  Quantification method of classification proces...          7
# 12  Three approaches to the quantitative definitio...          6
# 13             On Measures of Entropy and Information          0
# 14  Lower bounds to error probability for coding o...          0
# 15               Recent results in the Shannon theory          0
# 16                 The definition of random sequences          6
# 17              <i>Science and Information Theory</i>          1
# 18  Thermodynamics, An Introduction to the Physica...          1
# 19  Self-Consistent Equations Including Exchange a...          1
# 20                   Multi-way communication channels          0
# 21       Information Theory and Statistical Mechanics          1
# 22                                 Broadcast channels          0
# 23  A simple converse for broadcast channels with ...          0
# 24  Noiseless coding of correlated information sou...          0
# 25  Diversity in some south African diatom associa...          4
# 26             An Introduction to Information Theory.          6
# 27                                 Information Theory          0
# 28  A conditional entropy bound for a pair of disc...          0
# 29  Use of Algae, Especially Diatoms, in the Asses...          4
# 30                                 Information radius          0
# 31  A simple derivation of the coding theorem and ...          0
# 32  The Nonconcept of Species Diversity: A Critiqu...          4
# 33     A formal theory of inductive inference. Part I          6
# 34  The concept of a linguistic variable and its a...          7
# 35  A theorem on the entropy of certain binary seq...          0
# 36  A COMPOSITE RATING OF ALGAE TOLERATING ORGANIC...          4
# 37                     Science and information theory          1
# 38  The common information of two dependent random...          0
# 39  An achievable rate region for the broadcast ch...          0
# 40                     Information Theory and Coding.          1
# 41  An Introduction to the Physical Theories of Eq...          1
# 42  A proof of the data compression theorem of Sle...          0
# 43  Irreversibility and Heat Generation in the Com...          1
# 44    Mathematical Foundations of Information Theory.          1
# 45  Source coding with side information and a conv...          0
# 46  The concept of a linguistic variable and its a...          7
# 47  On Sequences of Pairs of Dependent Random Vari...          0
# 48  Random coding theorem for broadcast channels w...          0
# 49   Information Theory and Statistical Mechanics. II          1
# 50                           Intervall‐wertige Mengen          7
# 51  On the Length of Programs for Computing Finite...          6
# 52   A Class of Solutions for Group Decision Problems          7

# %% [markdown]
# ##3.2 Louvain and ARI

# %% [markdown]
# ### 3.2.1 Louvain
#
# I also apply the Louvain method in order to assess how robust the clustering results are with respect to a different community-detection algorithm.
#
# I experimented with different values of the `resolution` parameter. I report here the result for `resolution = 0.6`, because it yields a number of communities in the largest connected component that is reasonably close to the one obtained with Girvan–Newman (11 vs. 10), and therefore allows for a more meaningful comparison.

# %%
# Louvain
communities = nx.community.louvain_communities(
    Gcc,
    resolution=0.6,
    seed=42
)

print("Number of communities:", len(communities))
print("Sizes:", [len(c) for c in communities])

# modularity
mod = nx.community.modularity(Gcc, communities)
print("Modularity:", mod)
# Out:
# Number of communities: 11
# Sizes: [48, 14, 6, 99, 18, 31, 7, 26, 54, 36, 99]
# Modularity: 0.7776861878826569

# %% [markdown]
# ### 3.2.2 ARI
#
# I now compare the Girvan–Newman partition and the Louvain partition using the Adjusted Rand Index (ARI).
#
# The ARI provides a measure of similarity between two clustering solutions. Here it is used to assess whether the detected community structure is stable across different algorithms, or whether it is significantly affected by methodological choices.

# %%
#first we want two dictionaries, mapping the nodes (only belonging to Gcc) to their communities
gn_partition_filtered = {node: community_id for node, community_id in node_to_community.items() if node in Gcc.nodes()}

louvain_partition_filtered = {}
for i, community_set in enumerate(communities):
    for node in community_set:
        if node in Gcc.nodes():
            louvain_partition_filtered[node] = i

# %%
from sklearn.metrics import adjusted_rand_score

# Ensure both dictionaries have the same keys (nodes present in Gcc)
common_nodes = set(gn_partition_filtered.keys()) & set(louvain_partition_filtered.keys())

# Extract community labels in a consistent order
gn_labels = [gn_partition_filtered[node] for node in common_nodes]
louvain_labels = [louvain_partition_filtered[node] for node in common_nodes]

# Calculate Adjusted Rand Index
ari = adjusted_rand_score(gn_labels, louvain_labels)

print(f"Adjusted Rand Index (ARI) between Girvan-Newman and Louvain: {ari:.4f}")
# Out:
# Adjusted Rand Index (ARI) between Girvan-Newman and Louvain: 0.5646

# %% [markdown]
# # 4. Roles
#
# This section identifies the roles of **elaborators** and **translators**.
#
# These roles are central to Herfeld and Doehne’s account of scientific innovation. The point of the present analysis is not only to classify nodes, but also to assess whether these roles can be identified in a clear and robust way in the case of information theory.

# %% [markdown]
# ## 4.1 Elaborators
#
# Elaborators are defined here as nodes that belong to the epistemic core and whose within-community degree centrality is less than or equal to the **q-quantile** of the distribution within their community.
#
# This operationalization is meant to capture the idea that elaborators belong to the epistemic core but are not strongly integrated into a specialized area. Since Herfeld and Doehne do not provide a fully explicit threshold for what counts as “low” centrality, I test different values of `q`.

# %%
import numpy as np

"""
The function returns:
- a list of the elaborators
- a dataframe containing all the nodes of the core with infos about degree centrality in their cluster and whether they are elaborators or not

"""

def identify_elaborators(
    G,
    G_core,
    community_attr="community",
    within_deg_attr="within_cluster_degree",
    elaborator_attr="is_elaborator",
    threshold_value=0.5,   #q-quantile
    ignore_communities={-1},
):

    if threshold_value is None or not (0 <= threshold_value <= 1):
        raise ValueError("threshold_value must be between 0 and 1")

    community_map = nx.get_node_attributes(G, community_attr)

    # communities represented in the core
    core_communities = {
        community_map[node]
        for node in G_core.nodes()
        if community_map.get(node) not in ignore_communities
    }


    communities = {}
    for node, cid in community_map.items():
        if cid in ignore_communities or cid not in core_communities:
            continue
        communities.setdefault(cid, []).append(node)

    # within-cluster degree centrality
    within_deg = {}
    for cid, nodes in communities.items():
        H = G.subgraph(nodes)
        dc = nx.degree_centrality(H)
        within_deg.update(dc)

    nx.set_node_attributes(G, within_deg, within_deg_attr)

    # treshold for community
    thresholds = {}
    for cid, nodes in communities.items():
        vals = [within_deg[n] for n in nodes if n in within_deg]
        if not vals:
            continue
        thresholds[cid] = np.quantile(vals, threshold_value)


    elaborators = []
    node_flag = {n: False for n in G.nodes()}
    rows = []

    for node in G_core.nodes():
        cid = community_map.get(node, None)
        deg = within_deg.get(node, None)

        is_elaborator = (
            cid not in ignore_communities
            and cid in thresholds
            and deg is not None
            and deg <= thresholds[cid]
        )

        node_flag[node] = is_elaborator
        if is_elaborator:
            elaborators.append(node)

        rows.append({
            "node": node,
            "community": cid,
            "within_cluster_degree": deg,
            "threshold": thresholds.get(cid, None),
            "is_elaborator": is_elaborator,
        })

    nx.set_node_attributes(G, node_flag, elaborator_attr)

    df = pd.DataFrame(rows)
    df = df.merge(nodes_df[['node_id', 'title']], left_on='node', right_on='node_id', how='left') #add to the dataframe the title of publication
    df.drop(columns=['node_id'], inplace=True) # Drop the redundant node_id column from the merge

    return elaborators, df

# %%
elaborators, df = identify_elaborators(G, G_core, threshold_value = 0.5)



df[df["is_elaborator"]]
# Out:
#                                 node  community  within_cluster_degree  \
# 26  https://openalex.org/W2159977619          6               0.105263
#
#     threshold  is_elaborator                                   title
# 26   0.184211           True  An Introduction to Information Theory.

# %% [markdown]
# When **q = 0.5**, only one node in the epistemic core is identified as an elaborator. The number increases only slightly when the threshold is raised.
#
# This result is important for the broader argument of the paper: in this network, elaborators are difficult to identify in a clear way on the basis of the proposed analytical criterion.

# %%
elaborators, df = identify_elaborators(G, G_core, threshold_value = 0.6) #here q= 0.6



df[df["is_elaborator"]]
# Out:
#                                 node  community  within_cluster_degree  \
# 11  https://openalex.org/W2263958071          7               0.266667
# 26  https://openalex.org/W2159977619          6               0.105263
# 46  https://openalex.org/W4245152641          7               0.266667
# 50  https://openalex.org/W1976755248          7               0.266667
#
#     threshold  is_elaborator  \
# 11   0.266667           True
# 26   0.231579           True
# 46   0.266667           True
# 50   0.266667           True
#
#                                                 title
# 11  Quantification method of classification proces...
# 26             An Introduction to Information Theory.
# 46  The concept of a linguistic variable and its a...
# 50                           Intervall‐wertige Mengen

# %% [markdown]
# ## 4.2 Translators
#
# Translators are defined here as nodes whose within-community degree centrality is greater than or equal to the **q-quantile** of the distribution within their community, and that either belong to the epistemic core or are directly connected to it.
#
# This operationalization is meant to capture the idea that translators connect the epistemic core to more specialized areas, thereby enabling the innovation to spread across fields.

# %%
import numpy as np

#the function is similar to that for the elaborators

def identify_translators_quantile(
    G,
    G_core,
    community_attr="community",
    translator_attr="is_translator",
    within_deg_attr="within_cluster_degree",
    ignore_communities={-1},
    threshold_value=0.90,
):

    if threshold_value is None or not (0 <= threshold_value <= 1):
        raise ValueError("threshold_value must be between 0 and 1")

    community_map = nx.get_node_attributes(G, community_attr)
    core_nodes = set(G_core.nodes())

    communities = {}
    for node, cid in community_map.items():
        if cid not in ignore_communities:
            communities.setdefault(cid, []).append(node)

    within_deg_all = {}
    for cid, nodes in communities.items():
        H = G.subgraph(nodes)
        dc = nx.degree_centrality(H)
        within_deg_all.update(dc)

    nx.set_node_attributes(G, within_deg_all, within_deg_attr)

    thresholds = {}
    for cid, nodes in communities.items():
        vals = [within_deg_all[n] for n in nodes if n in within_deg_all]
        if not vals:
            continue
        thresholds[cid] = np.quantile(vals, threshold_value)

    translators = []
    translator_flag = {n: False for n in G.nodes()}
    rows = []

    for cid, nodes in communities.items():
        threshold = thresholds.get(cid, None)
        if threshold is None:
            continue

        for node in nodes:
            val = within_deg_all.get(node, None)
            if val is None:
                continue

            in_core = node in core_nodes
            connected_to_core = any(neigh in core_nodes for neigh in G.neighbors(node))

            in_top_quantile = val >= threshold
            is_valid_candidate = in_core or connected_to_core
            is_translator = in_top_quantile and is_valid_candidate

            if is_translator:
                translators.append(node)
                translator_flag[node] = True

            rows.append({
                "node": node,
                "community": cid,
                "within_cluster_degree": val,
                "threshold": threshold,
                "in_top_quantile": in_top_quantile,
                "in_core": in_core,
                "connected_to_core": connected_to_core,
                "is_valid_candidate": is_valid_candidate,
                "is_translator": is_translator,
            })

    nx.set_node_attributes(G, translator_flag, translator_attr)

    df = pd.DataFrame(rows)
    df = df.merge(nodes_df[['node_id', 'title', 'authors']], left_on='node', right_on='node_id', how='left') #add to the dataframe the title of publication and authors
    df.drop(columns=['node_id'], inplace=True) # Drop the redundant node_id column from the merge

    return translators, df

# %% [markdown]
# Let us first try with **q = 1**. Under this stricter criterion, we obtain 5 translators.

# %%
translators, df_translators = identify_translators_quantile(
    G,
    G_core,
    threshold_value=1
)
df_translators[df_translators["is_translator"]]
# Out:
#                                  node  community  within_cluster_degree  \
# 107  https://openalex.org/W1989008275          0               0.389610
# 228  https://openalex.org/W2040121225          7               0.466667
# 313  https://openalex.org/W2032558547          1               0.329670
# 402  https://openalex.org/W2104767862          4               0.354839
# 409  https://openalex.org/W2089442854          6               0.473684
#
#      threshold  in_top_quantile  in_core  connected_to_core  \
# 107   0.389610             True     True               True
# 228   0.466667             True     True               True
# 313   0.329670             True     True               True
# 402   0.354839             True     True               True
# 409   0.473684             True    False               True
#
#      is_valid_candidate  is_translator  \
# 107                True           True
# 228                True           True
# 313                True           True
# 402                True           True
# 409                True           True
#
#                                                  title  \
# 107      Information Theory and Reliable Communication
# 228  A definition of a nonprobabilistic entropy in ...
# 313       Information Theory and Statistical Mechanics
# 402  The Nonconcept of Species Diversity: A Critiqu...
# 409  A Machine-Independent Theory of the Complexity...
#
#                       authors
# 107             David A. Bell
# 228  Aldo de Luca; S. Termini
# 313              E. T. Jaynes
# 402        Stuart H. Hurlbert
# 409               Manuel Blum

# %% [markdown]
# With **q = 0.9**, the number of translators increases to 37.
#
# As discussed in the paper, however, the issue is not only the total number of translators, but also their distribution across communities. In this case, translators are not evenly distributed, which raises difficulties for the generality of the proposed role typology.

# %%
translators, df_translators = identify_translators_quantile(
    G,
    G_core,
    threshold_value=0.9
)
df_translators[df_translators["is_translator"]]
# Out:
#                                  node  community  within_cluster_degree  \
# 39   https://openalex.org/W2001935257          0               0.051948
# 46   https://openalex.org/W2087362480          0               0.045455
# 51   https://openalex.org/W2155676967          0               0.077922
# 53   https://openalex.org/W1993944611          0               0.084416
# 69   https://openalex.org/W2296441616          0               0.071429
# 89   https://openalex.org/W1991133427          0               0.058442
# 104  https://openalex.org/W4252822198          0               0.064935
# 106  https://openalex.org/W2947000318          0               0.084416
# 107  https://openalex.org/W1989008275          0               0.389610
# 112  https://openalex.org/W2128765501          0               0.064935
# 113  https://openalex.org/W3190595840          0               0.045455
# 117  https://openalex.org/W1592482298          0               0.051948
# 119  https://openalex.org/W2099213070          0               0.123377
# 122  https://openalex.org/W2122882636          0               0.045455
# 155  https://openalex.org/W2127768309          0               0.045455
# 176  https://openalex.org/W2043769961          0               0.071429
# 181  https://openalex.org/W2264297261          0               0.051948
# 186  https://openalex.org/W2130032292          0               0.045455
# 227  https://openalex.org/W2057178439          7               0.333333
# 228  https://openalex.org/W2040121225          7               0.466667
# 231  https://openalex.org/W4211007335          7               0.333333
# 240  https://openalex.org/W2157041604          7               0.333333
# 309  https://openalex.org/W1992649154          1               0.076923
# 312   https://openalex.org/W158805393          1               0.098901
# 313  https://openalex.org/W2032558547          1               0.329670
# 314  https://openalex.org/W4252028749          1               0.197802
# 315  https://openalex.org/W2317912355          1               0.131868
# 318  https://openalex.org/W4233798822          1               0.120879
# 322  https://openalex.org/W2087171258          1               0.098901
# 333  https://openalex.org/W1965555277          1               0.131868
# 350  https://openalex.org/W2596773272          1               0.065934
# 378  https://openalex.org/W2022825068          4               0.193548
# 380  https://openalex.org/W2064187509          4               0.193548
# 402  https://openalex.org/W2104767862          4               0.354839
# 408  https://openalex.org/W2135625884          6               0.421053
# 409  https://openalex.org/W2089442854          6               0.473684
# 426  https://openalex.org/W2005097301          6               0.421053
#
#      threshold  in_top_quantile  in_core  connected_to_core  \
# 39    0.045455             True     True               True
# 46    0.045455             True    False               True
# 51    0.045455             True     True               True
# 53    0.045455             True     True               True
# 69    0.045455             True     True               True
# 89    0.045455             True    False               True
# 104   0.045455             True     True               True
# 106   0.045455             True     True               True
# 107   0.045455             True     True               True
# 112   0.045455             True    False               True
# 113   0.045455             True     True               True
# 117   0.045455             True     True               True
# 119   0.045455             True     True               True
# 122   0.045455             True     True               True
# 155   0.045455             True     True               True
# 176   0.045455             True     True               True
# 181   0.045455             True    False               True
# 186   0.045455             True    False               True
# 227   0.333333             True     True               True
# 228   0.333333             True     True               True
# 231   0.333333             True    False               True
# 240   0.333333             True     True               True
# 309   0.064835             True     True               True
# 312   0.064835             True     True               True
# 313   0.064835             True     True               True
# 314   0.064835             True     True               True
# 315   0.064835             True     True               True
# 318   0.064835             True     True               True
# 322   0.064835             True     True               True
# 333   0.064835             True    False               True
# 350   0.064835             True     True               True
# 378   0.190323             True    False               True
# 380   0.190323             True    False               True
# 402   0.190323             True     True               True
# 408   0.421053             True     True               True
# 409   0.421053             True    False               True
# 426   0.421053             True     True               True
#
#      is_valid_candidate  is_translator  \
# 39                 True           True
# 46                 True           True
# 51                 True           True
# 53                 True           True
# 69                 True           True
# 89                 True           True
# 104                True           True
# 106                True           True
# 107                True           True
# 112                True           True
# 113                True           True
# 117                True           True
# 119                True           True
# 122                True           True
# 155                True           True
# 176                True           True
# 181                True           True
# 186                True           True
# 227                True           True
# 228                True           True
# 231                True           True
# 240                True           True
# 309                True           True
# 312                True           True
# 313                True           True
# 314                True           True
# 315                True           True
# 318                True           True
# 322                True           True
# 333                True           True
# 350                True           True
# 378                True           True
# 380                True           True
# 402                True           True
# 408                True           True
# 409                True           True
# 426                True           True
#
#                                                  title  \
# 39                A coding theorem and Rényi's entropy
# 46    A heuristic discussion of probabilistic decoding
# 51   A proof of the data compression theorem of Sle...
# 53   A simple derivation of the coding theorem and ...
# 69                                  Broadcast channels
# 89   Error bounds for convolutional codes and an as...
# 104                                 Information radius
# 106                                 Information Theory
# 107      Information Theory and Reliable Communication
# 112                     Low-density parity-check codes
# 113  Lower bounds to error probability for coding o...
# 117                   Multi-way communication channels
# 119  Noiseless coding of correlated information sou...
# 122             On Measures of Entropy and Information
# 155  Source coding with side information and a conv...
# 176                               The Wire-Tap Channel
# 181                       Transmission of Information.
# 186  Trellis Encoding of memoryless discrete-time s...
# 227   A Class of Solutions for Group Decision Problems
# 228  A definition of a nonprobabilistic entropy in ...
# 231                                         Fuzzy sets
# 240  The concept of a linguistic variable and its a...
# 309              <i>Science and Information Theory</i>
# 312                     Information Theory and Coding.
# 313       Information Theory and Statistical Mechanics
# 314   Information Theory and Statistical Mechanics. II
# 315                 Information Theory and Statistics.
# 318  Irreversibility and Heat Generation in the Com...
# 322    Mathematical Foundations of Information Theory.
# 333                     On Information and Sufficiency
# 350                     Science and information theory
# 378  Diversity and Evenness: A Unifying Notation an...
# 380  Diversity of Planktonic Foraminifera in Deep-S...
# 402  The Nonconcept of Species Diversity: A Critiqu...
# 408    A formal theory of inductive inference. Part II
# 409  A Machine-Independent Theory of the Complexity...
# 426  Three approaches to the quantitative definitio...
#
#                                                authors
# 39                                      L. L. Campbell
# 46                                      Robert M. Fano
# 51                                     Thomas M. Cover
# 53                                  Robert G. Gallager
# 69                                     Thomas M. Cover
# 89                                   Andrew J. Viterbi
# 104                                       Robin Sibson
# 106                                             R. Ash
# 107                                      David A. Bell
# 112                                 Robert G. Gallager
# 113  Claude E. Shannon; Robert G. Gallager; Elwyn R...
# 117                                    Rudolf Ahlswede
# 119                              D. Slepian; J.K. Wolf
# 122                                           A. Rényi
# 155                      Rudolf Ahlswede; János Körner
# 176                                         A.D. Wyner
# 181                    Amiel Feinstein; Robert M. Fano
# 186                     Andrew J. Viterbi; J. K. Omura
# 227                                           P. L. Yu
# 228                           Aldo de Luca; S. Termini
# 231                                        L. A. Zadeh
# 240                                        L. A. Zadeh
# 309                    Léon Brillouin; R. W. Hellwarth
# 312                            I. J. Good; N. Abramson
# 313                                       E. T. Jaynes
# 314                                       E. T. Jaynes
# 315                           Meyer Dwass; S. Kullback
# 318                                      Rolf Landauer
# 322  J. Laurie Snell; Aleksandr I︠A︡kovlevich Khinc...
# 333                         S. Kullback; R. A. Leibler
# 350                                           S. Charp
# 378                                         M. O. Hill
# 380                 Wolfgang Berger; Frances L. Parker
# 402                                 Stuart H. Hurlbert
# 408                                  Ray J. Solomonoff
# 409                                        Manuel Blum
# 426                                   A. N. Kolmogorov

# %%
df_translators[df_translators["is_translator"]].shape
# Out:
# (37, 11)

# %% [markdown]
# # 5. Concluding Remark
#
# The notebook documents the computational side of the analysis. Its main result is not simply a classification of nodes, but the emergence of several methodological and interpretive difficulties: the epistemic core depends on analytical choices, community detection is only partly stable, and the roles of elaborators and translators are not straightforwardly recoverable from the topology alone.
#
# For the philosophical significance of these results, see the accompanying paper.
